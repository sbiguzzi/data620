# %% [markdown]
# # Homework 2.2 - Assignment: Centrality Measures
# ###### Stefano Biguzzi, Ian Costello, Dennis Pong
#
# ## Assignment Description
# Centrality measures can be used to predict (positive or negative) outcomes for a node.
#
# Your task in this week’s assignment is to identify an interesting set of network data that is available on the web (either through web scraping or web APIs) that could be used for analyzing and comparing centrality measures across nodes.  As an additional constraint, there should be at least one categorical variable available for each node (such as “Male” or “Female”; “Republican”, “Democrat,” or “Undecided”, etc.)
#
# In addition to identifying your data source, you should create a high level plan that describes how you would load the data for analysis, and describe a hypothetical outcome that could be predicted from comparing degree centrality across categorical groups.
#
# For this week’s assignment, you are not required to actually load or analyze the data.
#
# You may work in a small group on the assignment.   You should post your document to GitHub by end of day on Sunday.
#
# ## Assignment Steps
# ### Data Set Identification - Twitch APIs
# The data sets that we have identified are from "Twitch" a streaming service geared toward video games and gamers. Twitch has become quite popular to view both recordings and real-time "let's plays." Streamers and video game companies alike benefit from this service to build followings and market new games.
#
# Twitch offers a [third-party developer API setup](https://dev.twitch.tv/docs/api) to access game and user data. We would seek to connect directly to this API to drawn in the network data focused on the most popular games, their genre, user engagement, and language of users.
#
# ### Landscape Analysis of the Data Set
#
# From [the streams API set](https://dev.twitch.tv/docs/api/reference#get-streams):
#
# ![Assignment2.2_1.png](attachment:Assignment2.2_1.png)
#
# - stream_id: record ID of each stream
# - game_id: Twitch game ID to be connected from another view to get genre
# - game_name: Title of the game streamed
# - user_id: ID of user streaming
# - type: Twitch stream type, whether live or recorded
# - viewer_count: Number of viewers of stream
# - language: Stream language from Twitch
# - started_at: UTC timestamp to calculate length of stream
#
# ### Predictions Based on Categorical Groups
#
# We would connect streams to user IDs and streams in a netword to understand which users have the most streams for which games. Based on the streams, we would layer in the categorical data to ascertain characteristics of the streams - and therefore streamers. Such predictions may include:
#
# 1. English would likely be the leading language for the most engaged streams
# Based on the saturation of the English language in game development overall, it would stand to reason that the streams of games conducted in English would also be the most engaged. Potentially Japanese, Korean, and Chinese, following close behind.
#
# 2. Game Genres
# Though completely a hypothesis, game genres that may be most engaged may be multiplayer and conpetitive (first-person shooters e.g., Counterstrike and fantasy battle games e.g., Dota 2).
#
# 3. More prolific streamers would have more engagement per stream
# That is to say, users with more streams would have on balance more viewers for each stream than users with few streams.
